# %% [markdown]
# # **Project Name**    -
# Flipkart Customer Support Data Analysis

# %% [markdown]
#  **Project Type**    - EDA
# ##### **Contribution**    - Individual
# ##### **Team Member 1 -** Bhagyalaxmi Samantara
# ##### **Team Member 2 -** N/A
# ##### **Team Member 3 -** N/A
# ##### **Team Member 4 -** N/A

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# This project aims to explore the Flipkart Customer Support dataset using Exploratory Data Analysis (EDA). The objective is to understand customer support activities, identify common issues faced by customers, and discover patterns that can help improve service quality and customer satisfaction.
#
# **Project Workflow:**
#
# **Data Preparation:**
# The dataset was examined carefully before analysis. Missing values, duplicate records, and inconsistent data were handled to improve data quality and ensure accurate results.
#
# **Exploratory Analysis:**
# Python libraries such as Pandas, NumPy, Matplotlib, and Seaborn were used to analyze the dataset. Different visualizations, including bar charts, histograms, pie charts, count plots, and heatmaps, were created to better understand customer support trends.
#
# **Major Findings:** The analysis focuses on identifying:
#
# * Frequently reported customer support issues.
# *   Distribution of support requests across different product categories.
#
# *   Usage of different customer support channels.
#
# *  Relationship between response time and customer satisfaction.
#
# *  Overall ticket resolution patterns and support performance.
#
# This project demonstrates how EDA can transform raw customer support data into meaningful business insights. The results can help improve customer service, reduce response time, and support better business decisions through data-driven analysis.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/Bhagyalaxmi-Samantara/Flipkart-Customer-Support-EDA/blob/main/Flipkart_Customer_Support_EDA.ipynb

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# This dataset is related to analyzing customer support activities on the Flipkart platform, allowing us to extract valuable insights that can improve customer service and business performance.
#
# **Customer Issues:** Understanding the most common customer complaints and support requests is essential for improving service quality. This analysis helps identify the major issues faced by customers.
#
# **Support Performance:** Evaluating response time, resolution status, and support efficiency helps measure the effectiveness of the customer support system and identify areas for improvement.
#
# **Customer Satisfaction:** Analyzing customer satisfaction scores and their relationship with support performance provides valuable insights into customer experience and service quality.
#
# **Support Channels & Trends:** Examining the usage of different support channels and identifying trends in customer interactions helps optimize support operations and improve overall customer satisfaction.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# The business objective of this project is to analyze Flipkart customer support data, identify common customer issues, evaluate support performance, and generate insights to improve customer satisfaction and service quality.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ### Dataset Loading

# %%
import pandas as pd
df = pd.read_csv('/content/Customer_support_data.csv')

# %% [markdown]
# ### Dataset First View

# %%
df.head()

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
df.shape

# %% [markdown]
# ### Dataset Information

# %%
df.info()

# %% [markdown]
# #### Duplicate Values

# %%
df.duplicated().sum()

# %% [markdown]
# #### Missing Values/Null Values

# %%
df.isnull().sum()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12,6))
sns.heatmap(df.isnull(), cbar=False)
plt.show

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# The dataset contains customer support records with 85,907 rows and 20 columns. It includes customer details, order details, issue category, support channel, response time, and CSAT score. No duplicate records were found, while some columns contain missing values. The dataset can be used to analyze customer service performance and satisfaction.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
df.columns

# %%
df.describe

# %% [markdown]
# ### Variables Description

# %% [markdown]
# The dataset contains variables such as Unique ID, Channel Name, Category, Sub-category, Customer Remarks, Order ID, Order Date, Issue Reported, Issue Responded, Survey Response Date, Customer City, Product Category, Item Price, Connected Handling Time, Agent Name, Supervisor, Manager, Tenure Bucket, Agent Shift, and CSAT Score. These variables describe customer support interactions and satisfaction.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
for col in df.columns:
  print(col)
  print(df[col].nunique())
  print("-"*40)

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
df.isnull().sum()
df.duplicated().sum()
df = df.drop_duplicates()
df.shape

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# I checked the dataset for missing values and duplicate records. No duplicate records were found. Missing values were identified in some columns. The dataset was cleaned and prepared for analysis. The data contains customer support information, issue categories, response details, and CSAT scores, which can be used to analyze customer satisfaction and service performance.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,5))
sns.countplot(data=df, x='category')
plt.xticks(rotation=45)
plt.title("Count of Customer Support Categories")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I selected a count plot because it clearly shows the frequency of customer support requests in each category and makes comparison easy.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows that some categories receive more customer queries than others. This helps identify the most common issues faced by customers.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. The organization can focus on the categories with the highest number of issues, improve service quality, reduce response time, and increase customer satisfaction. High query volumes in certain categories may indicate areas that need process improvement.

# %% [markdown]
# #### Chart - 2

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("/content/Customer_support_data.csv")

plt.figure(figsize=(8,5))
sns.countplot(data=df, x='CSAT Score')
plt.title("Distribution of CSAT Scores")
plt.show()

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows the frequency of each CSAT score. It helps identify whether customers are mostly satisfied or dissatisfied with the support service.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights can create a positive business impact. By analyzing customer satisfaction (CSAT) scores, the company can identify areas that need improvement, reduce customer complaints, and improve service quality. If some categories have consistently low CSAT scores, they may negatively affect customer satisfaction, customer retention, and business growth. The company should focus on these areas to improve overall performance.

# %% [markdown]
# #### Chart - 3

# %%
plt.figure(figsize=(10,5))
sns.countplot(data=df, x='channel_name')
plt.xticks(rotation=45)
plt.title("Customer Support Requests by Channel")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I selected a count plot because it clearly compares the number of customer support requests across different support channels.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows which customer support channel receives the highest number of requests. This helps identify the most frequently used communication channel by customers.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. The analysis helps the company allocate staff and resources to the busiest support channels, improving response time and customer satisfaction. If one channel has significantly more requests or poor performance, it may lead to delays, lower customer satisfaction, and negative business growth. Improving that channel can enhance the overall customer experience.

# %% [markdown]
# #### Chart - 4

# %%
plt.figure(figsize=(12,6))
sns.countplot(data=df, y='Customer_City', order=df['Customer_City'].value_counts().head(10).index)
plt.title("Top 10 Customer Cities")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I selected a count plot because it clearly compares the number of customer support requests from different cities and highlights the top contributing locations.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows the top cities with the highest number of customer support requests. It helps identify regions where customers face more issues or where demand for support is higher.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. These insights help the company allocate support resources to high-demand cities, improve service quality, and respond more efficiently. If a particular city has an unusually high number of complaints, it may indicate service or product issues in that region, which can reduce customer satisfaction and negatively impact business growth if not addressed.

# %% [markdown]
# #### Chart - 5

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['Item_price'], bins=30, kde=True)
plt.title("Distribution of Item Price")
plt.xlabel("Item Price")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I selected a histogram because it shows the distribution of item prices and helps identify the most common price ranges, as well as any outliers.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows how item prices are distributed. Most products are concentrated within a particular price range, while a few products have much higher prices.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. The price distribution helps the company understand customer purchasing patterns and identify the most popular price ranges. If very high-priced items receive more complaints or low CSAT scores, it may indicate pricing or quality issues that could negatively affect customer satisfaction and business growth. Addressing these issues can improve customer trust and sales.

# %% [markdown]
# #### Chart - 6

# %%
plt.figure(figsize=(12,6))
sns.boxplot(data=df, x='category', y='CSAT Score')
plt.xticks(rotation=45)
plt.title("CSAT Score by Category")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I selected a box plot because it compares the distribution of CSAT scores across different categories and helps identify variations and outliers.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows that customer satisfaction varies across different categories. Some categories have consistently higher CSAT scores, while others have lower scores, indicating areas that need improvement.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. The insights help identify categories with low customer satisfaction so the company can improve service quality, reduce complaints, and increase customer loyalty. Categories with consistently low CSAT scores may negatively affect customer retention and business growth if corrective actions are not taken.

# %% [markdown]
# #### Chart - 7

# %%
plt.figure(figsize=(8,5))
sns.countplot(data=df, x='Agent Shift')
plt.title("Distribution of Agent Shifts")
plt.xlabel("Agent Shift")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I selected a count plot because it clearly shows the number of customer support cases handled in each agent shift, making comparison easy.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows the distribution of support requests across different agent shifts. It helps identify which shift handles the highest workload and whether the workload is balanced.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. The insights help the company optimize staff allocation and improve response time during busy shifts. If one shift consistently handles a much higher workload than others, it may lead to longer waiting times, employee overload, lower customer satisfaction, and negatively impact business growth.

# %% [markdown]
# #### Chart - 8

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['connected_handling_time'], bins=30, kde=True)
plt.title("Distribution of Connected Handling Time")
plt.xlabel("Connected Handling Time")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I selected a histogram because it clearly shows the distribution of customer handling time and helps identify the most common handling duration and any outliers.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows that most customer queries are resolved within a particular handling time range, while a few cases require much longer time. This helps identify the efficiency of customer support operations.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. The insights help improve customer service efficiency by identifying delays in handling customer issues. Longer handling times may increase customer waiting time, reduce satisfaction, and negatively impact business growth. Reducing handling time can improve customer experience and operational performance.

# %% [markdown]
# #### Chart - 9

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data=df, x='channel_name', y='CSAT Score')
plt.xticks(rotation=45)
plt.title("CSAT Score by Support Channel")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I selected a box plot because it compares customer satisfaction (CSAT) scores across different support channels and highlights the variation in customer experience.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows how customer satisfaction differs across support channels. Some channels have higher median CSAT scores, while others show greater variation and lower satisfaction.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. The company can identify support channels with lower CSAT scores and improve their service quality. Poor-performing channels may reduce customer satisfaction and loyalty, which can negatively affect business growth if not addressed.

# %% [markdown]
# #### Chart - 10

# %%
plt.figure(figsize=(8,5))
sns.boxplot(y=df['connected_handling_time'])
plt.title("Connected Handling Time Distribution")
plt.ylabel("Connected Handling Time")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I selected a box plot because it helps identify the spread of handling time, median values, and outliers.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most customer issues are resolved within a similar time range, while a few cases have exceptionally high handling times, indicating possible delays.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights can create a positive business impact. The box plot helps identify unusually long handling times (outliers) and variations in support performance. By reducing excessive handling time and improving service efficiency, the company can enhance customer satisfaction and optimize resource utilization. If many cases have very high handling times, it may lead to slower issue resolution, customer dissatisfaction, and increased operational costs, which can negatively affect business growth.

# %% [markdown]
# #### Chart - 11

# %%
plt.figure(figsize=(8,5))
sns.violinplot(data=df, x='Agent Shift', y='CSAT Score')
plt.title("CSAT Score by Agent Shift")
plt.xlabel("Agent Shift")
plt.ylabel("CSAT Score")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I selected a violin plot because it shows the distribution and density of CSAT scores across different agent shifts, making it easy to compare customer satisfaction levels.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart compares customer satisfaction across different agent shifts. It helps identify whether a particular shift consistently receives higher or lower CSAT scores.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. The insights help management evaluate the performance of different agent shifts and allocate resources more effectively. If one shift consistently receives lower CSAT scores, it may indicate staffing, training, or workload issues. Addressing these issues can improve customer satisfaction and overall business performance.

# %% [markdown]
# #### Chart - 12

# %%
plt.figure(figsize=(10,6))
sns.countplot(data=df, y='Product_category', order=df['Product_category'].value_counts().index)
plt.title("Distribution of Product Categories")
plt.xlabel("Count")
plt.ylabel("Product Category")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I selected a count plot because it clearly shows the number of customer support cases for each product category and allows easy comparison.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows which product categories receive the highest and lowest number of customer support requests. This helps identify products that require more customer support attention.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. The insights help the company identify product categories with a high number of support requests. By improving the quality of these products or providing better customer support, the company can reduce complaints and increase customer satisfaction. Product categories with consistently high complaint volumes may negatively impact customer trust and business growth if the underlying issues are not resolved.

# %% [markdown]
# #### Chart - 13

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(data=df, x='Item_price', y='connected_handling_time')
plt.title("Item Price vs Connected Handling Time")
plt.xlabel("Item Price")
plt.ylabel("Connected Handling Time")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I selected a scatter plot because it helps visualize the relationship between item price and connected handling time.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows whether higher-priced items require more handling time. It also helps identify patterns, trends, or any unusual cases (outliers).

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. The company can identify whether expensive products require longer support time and allocate resources accordingly. If higher-priced products consistently take much longer to resolve, it may reduce customer satisfaction and increase operational costs, which can negatively impact business growth.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8,6))

numeric_df = df.select_dtypes(include=['number'])

sns.heatmap(numeric_df.corr(),
            annot=True,
            cmap='coolwarm',
            linewidths=0.5)

plt.title("Correlation Heatmap of Numerical Features")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I selected a correlation heatmap because it helps visualize the relationship between numerical variables. It makes it easy to identify positive, negative, or weak correlations among different features.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The heatmap shows the correlation between numerical variables such as Item Price, Connected Handling Time, and CSAT Score. Most variables show weak to moderate correlations, indicating that each feature contributes differently to customer support performance.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt


numeric_df = df[['Item_price', 'connected_handling_time', 'CSAT Score']]

sns.pairplot(numeric_df)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I selected a pair plot because it provides a comprehensive view of the relationships and distributions among all numerical variables in the dataset. It helps identify trends, patterns, and possible correlations in a single visualization.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The pair plot shows the distribution of each numerical variable and the relationships between them. It helps identify clusters, outliers, and whether variables such as Item Price, Connected Handling Time, and CSAT Score have any noticeable association.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# To achieve the business objective, the company should focus on improving customer support efficiency and customer satisfaction. High handling times should be reduced by providing better agent training and optimizing workflows. Product categories with a high number of complaints should be analyzed to identify root causes and improve product quality. Regular monitoring of CSAT scores and customer feedback will help identify areas for improvement. Efficient resource allocation across different channels and agent shifts can further enhance service quality, resulting in higher customer satisfaction, increased customer retention, and overall business growth.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# This project analyzed customer support data to understand customer satisfaction, support performance, and key business trends. Data cleaning and exploratory data analysis (EDA) helped identify patterns in customer complaints, handling time, product categories, and CSAT scores. The visualizations showed that customer satisfaction is influenced by multiple factors, including handling time and support performance. The insights obtained from this analysis can help the company improve service quality, optimize resource allocation, reduce issue resolution time, and enhance customer experience. Overall, the project demonstrates how data-driven decision-making can support business growth and improve customer satisfaction.
